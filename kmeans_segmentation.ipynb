# %% [markdown]
# <a href="https://colab.research.google.com/github/SruthiChilukuri/Master-Project/blob/master/kmeans_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Performing Image segmentation using kmeans clustering**
#
# - Used same image scrapped from amazon(us) website
# - the 3-dimensional image was first converted into a 2D array; with shape (length*width, # of channels)
# - fitted the kmeans algorithm to create clusters of pixels
# - couldn't perform segmentation using this approach.
# - Found out that k-means works well on small datasets and is not suitable for **non-convex clusters**.
# - our image is real-time and is not a convex structure.
# - Hence, we don't intend to use clustering to perform segemntation for our fashion recomendations system.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-892f6203-99ab-4bd9-851a-9c2c63a0e72f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-892f6203-99ab-4bd9-851a-9c2c63a0e72f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving amazon1.png to amazon1.png

# %%
import matplotlib.pyplot as plt
image = plt.imread('amazon1.png')
image.shape
plt.imshow(image)

# %%
pic = plt.imread('amazon1.png')/255
print(pic.shape)
#plt.imshow(pic)

# %%
pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
pic_n.shape
# Out:
# (361746, 4)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=0).fit(pic_n)
pic2show = kmeans.cluster_centers_[kmeans.labels_]

# %%
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
plt.imshow(cluster_pic)
